# %% [markdown]
# ### 1 Comp. Mod.: MHD
#
# fluids, models, assumptions? --> classical field theory (vel. temp. magn.)
#
# dim.less nabla & time: $\hat{\nabla} = L \nabla \quad \partial_\hat{t} = \tau \partial_t$
#
# same for $B,E,j,v$ --> $v = L/\tau \ll c$ (non-rel.)
#
# lor. force is actually force dens.
#
# flux tubes, along field lines, important: div. free Maxw. eq. constr. B topologies
#
# set terms ~0 to neglect --> strong assumption on charge dens. (misleading???)
#
# local models, higher freq. waves, but simple global model not resolved (slower)
#
# $\beta \gg 1$ / $\beta \ll 1$
#
# rad. / mag. driven plasma, is it this?
#
# example for ideal & slow: solar physics applications
#
# what makes ideal mhd ideal? --> specific def. of added eq. that closes system: generalized ohms law --> "derive" with Lorentz transform, rel. with el. field and curr. dens.
#
# gyrate many times before collision (magnetized plasma assumption --> simplified gen. ohm law, resistive mhd)
#
# if electrons start to decouple: magn. assumption breaks --> must include additional terms (weakest, breaks first)
#
# means that mag. field topology cannot change over time, all lines glued together / connected etc...
#
# moving surface means that time differential and surface integral operators cannot be exchanged trivially
#
# we get const. magn. flux along comoving surface with fluid (Alfven theorem)
#
# field lines (e.g. around sun differential rot.) will twist from poloidal to toroidal shape
